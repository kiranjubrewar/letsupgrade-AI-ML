# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# dataset1=pd.read_excel(‘general_data.xlsx', sheet_name=0) 
dataset1=pd.read_csv("C:/Users/kiran/Downloads/datasets/general_data.csv") 
                       
dataset1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
dataset1.dropna()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset1.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
dataset1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
dataset1.isnull().count()
# Out:
# Age                        4410
# Attrition                  4410
# BusinessTravel             4410
# Department                 4410
# DistanceFromHome           4410
# Education                  4410
# EducationField             4410
# EmployeeCount              4410
# EmployeeID                 4410
# Gender                     4410
# JobLevel                   4410
# JobRole                    4410
# MaritalStatus              4410
# MonthlyIncome              4410
# NumCompaniesWorked         4410
# Over18                     4410
# PercentSalaryHike          4410
# StandardHours              4410
# StockOptionLevel           4410
# TotalWorkingYears          4410
# TrainingTimesLastYear      4410
# YearsAtCompany             4410
# YearsSinceLastPromotion    4410
# YearsWithCurrManager       4410
# dtype: int64

# %%
from scipy.stats import norm

# %%
dataset1.std()
# Out:
# Age                            9.133301
# DistanceFromHome               8.105026
# Education                      1.023933
# EmployeeCount                  0.000000
# EmployeeID                  1273.201673
# JobLevel                       1.106689
# MonthlyIncome              47068.888559
# NumCompaniesWorked             2.498887
# PercentSalaryHike              3.659108
# StandardHours                  0.000000
# StockOptionLevel               0.851883
# TotalWorkingYears              7.782222
# TrainingTimesLastYear          1.288978
# YearsAtCompany                 6.125135
# YearsSinceLastPromotion        3.221699
# YearsWithCurrManager           3.567327
# dtype: float64

# %%
dataset1.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
from scipy.stats import wilcoxon

# %%
stats,p=wilcoxon(dataset1.Age,dataset1.Education)
print(stats ,p)
# Out:
# 0.0 0.0

# %%
stats,p=wilcoxon(dataset1.Education,dataset1.JobLevel)
print(stats ,p)
# Out:
# 1146648.0 8.724635739045322e-236

# %%
from scipy.stats import friedmanchisquare

# %%
stats,p=friedmanchisquare(dataset1.EmployeeCount,dataset1.Age,dataset1.Education)
print(stats ,p)
# Out:
# 8587.77583187391 0.0

# %%
from scipy.stats import kruskal

stats,p=kruskal(dataset1.EmployeeCount,dataset1.Age,dataset1.Education)
print(stats ,p)
# Out:
# 11761.29467062832 0.0

# %%
from scipy.stats import chi2_contingency

dataset1.dropna()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
tab = pd.crosstab(dataset1.Age,dataset1.Education)
tab
# Out:
# Education   1   2    3   4   5
# Age
# 18          0   0    9  12   3
# 19          0  12    9   6   0
# 20          0   3   18  12   0
# 21          3  15    9   6   6
# 22          6  12   18   9   3
# 23          3   6   21  12   0
# 24          6  15   33  12  12
# 25         12  24   21  18   3
# 26         12  30   45  30   0
# 27          9  24   66  42   3
# 28         12  18   69  39   6
# 29         18  39   75  66   6
# 30          9  21   96  48   6
# 31         36  39   66  57   9
# 32         27  24   84  45   3
# 33          9  48   66  45   6
# 34         30  57   75  57  12
# 35         36  42   84  66   6
# 36         24  36  111  36   0
# 37         21  21   63  33  12
# 38          9  42   69  48   6
# 39         24  12   42  42   6
# 40         18  24   66  60   3
# 41         15  24   48  30   3
# 42         21  24   36  57   0
# 43          6  30   30  21   9
# 44         15  27   33  21   3
# 45         27  24   45  24   3
# 46         24   9   39  27   0
# ...

# %%
stats,p,dof,expeted=chi2_contingency(tab)
print(stats,p)
# Out:
# 506.1081947525774 1.3867873539299397e-35

# %%
from scipy.stats import ttest_rel

stats,p=ttest_rel(dataset1.EmployeeCount,dataset1.Education)
print(stats ,p)
# Out:
# -124.06403272725407 0.0
